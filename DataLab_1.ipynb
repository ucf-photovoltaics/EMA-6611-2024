# %% [markdown]
# # EMA 6611 - DataLab Assignment 1
# Complete each of the steps below and submit this by **October 7, 2024**.

# %%
suppressPackageStartupMessages(library(tidyverse))

library(readr)
library(ggplot2)
library(tidyverse)
library(plyr)
library(dplyr)
library(readr)
library(scales)
library(reshape2)

# %% [markdown]
# ### Task 1 - 5 points
#
# Rename this file as: EMA_6611_Datalab_1_YourLastName_YourFirstName_YourNID

# %% [markdown]
# ## Complete Literature Summary Table Version 1

# %% [markdown]
# ### Task 2 - 5 points
#
# - Download the Excel file in the Data folder for this workbook (on the right).
# - In the subsequent tasks, you will fill out this table. Every row will represent one of the articles you found for the previous assignment where you created the BibTeX file or one of the datasheets you found previously.
# - Make sure you have all of the articles and datasheets saved on your computer and/or your prefered cloud storage location (e.g., OneDrive, Google Drive).

# %% [markdown]
# ### Task 3 - 10 points
#
# Select one of the research articles you found and included in your BibTex file, and fill out the following in the first row of your table.
#
# **Author or Company** - Insert the last name of the first author
#
#
# **Article DOI or Datasheet URL** - Insert the DOI URL (i.e., DOI hyperlink) for the article. It should look like this, https://doi.org/10.1016/j.solmat.2024.112715.
#
#
# **Type of Device** - Select the type of device your are working on
# - LED-UV
# - LED-Visible
# - LED-IR
# - PV-Si
# - PV-CdTe
# - PV-Tandem
# - Photodetector-UV
# - Photodetector-Visible
# - Photodetector-IR
#
# **Absorber or Emitter Material** - Enter the chemical formula for the absorber or emitter semiconductor material used in this device in this article
#
#
# **Absorber or Emitter Crystallinity** - Select one of the following options below. NA means not available.
# - Monocrystalline
# - Polycrystalline
# - Amorphous
# - NA
#
#
# **Absorber or Emitter Bandgap Type** - Select one of the following options below. Only enter N/A after your done some searching on that material and couldn't find the answer.
# - Direct
# - Indirect
# - NA
#
#
# **Absorber or Emitter Bandgap Value (eV)** - Enter the bandgap value in eV here. Only enter N/A after your done some searching on that material and couldn't find the answer.
#
#
# **Front surface optics** - Select one of the following options below.
# - Planar - No Coating
# - Planar - With Coating(s)
# - Textured - No Coating
# - Textured - With Coating(s)
# - NA
#
#
# **Rear surface optics** - Select one of the following options below.
# - Planar - No Coating
# - Planar - With Coating(s)
# - Textured - No Coating
# - Textured - With Coating(s)
# - NA

# %% [markdown]
# ### Task 4 - 150 points
#
# Repeat the steps of Task 3 for the remaining articles.

# %% [markdown]
# ### Task 5 - 10 points
#
# Select one of your datasheets, and fill out the following in the first row of your table.
#
#
# **Author or Company** - Insert the manufacturer's name in this cell
#
#
# **Article DOI or Datasheet URL** - Insert the URL (i.e., website link) for the datasheet
#
#
# **Type of Device** - Select the type of device this is
# - LED-UV
# - LED-Visible
# - LED-IR
# - PV-Si
# - PV-CdTe
# - PV-Tandem
# - Photodetector-UV
# - Photodetector-Visible
# - Photodetector-IR
#
# **Absorber or Emitter Material** - Enter the chemical formula for the absorber or emitter semiconductor material used in this device
#
#
# **Absorber or Emitter Crystallinity** - Select one of the following options below. NA means not available.
# - Monocrystalline
# - Polycrystalline
# - Amorphous
# - NA
#
#
# **Absorber or Emitter Bandgap Type** - Select one of the following options below. Only enter N/A after your done some searching on that material and couldn't find the answer.
# - Direct
# - Indirect
# - NA
#
#
# **Absorber or Emitter Bandgap Value (eV)** - Enter the bandgap value in eV here. Only enter N/A after your done some searching on that material and couldn't find the answer.
#
#
# **Front surface optics** - Select one of the following options below.
# - Planar - No Coating
# - Planar - With Coating(s)
# - Textured - No Coating
# - Textured - With Coating(s)
# - NA
#
#
# **Rear surface optics** - Select one of the following options below.
# - Planar - No Coating
# - Planar - With Coating(s)
# - Textured - No Coating
# - Textured - With Coating(s)
# - NA

# %% [markdown]
# ### Task 6 - 50 points
#
# Repeat the steps of Task 5 for the remaining datasheets.

# %% [markdown]
# ### Task 7 - 5 points
#
# Replace the empy Table_1.xlsx Excel file in this workbook with your completed file. Do not change the filename. Make sure to save a copy of this on your computer as well!
#
# You can do this by first deleting the empty Excel file in the Data folder within this workbook. Then, click the three dots near the Data folder and click "Upload into folder" and select the new file with completed entries.

# %% [markdown]
# ### Task 8 - 5 points
#
# Export this sheet as a CSV file and upload it to the Data folder. CSV files are easy to read with coding languages like _R_ and _Python_.
#
# To do this, in Excel you can "Save a Copy" and select the CSV option. Keep the filename, so now it will be Table_1.csv. Then, upload it into the Data folder.

# %% [markdown]
# ### Task 9 - 20 points of extra credit
#
# - Read in the CSV file
# - Turn it into a dataframe
# - Plot the publications vs. year as a barchart

# %% [markdown]
# ## Solve the Following Problem Set

# %% [markdown]
# ### Problem 1
#
# The complex refractive index versus wavelength for four materials is provided in the following _.csv_ files in this Workspace.
#
# - _Material_A.csv_
# - _Material_B.csv_
# - _Material_C.csv_
# - _Material_D.csv_
#
# Run the _R_ code below to read in these _.csv_ files, plot the data, and then estimate the approximate band gap ($E_{g}$) of each material and provide an explanation of how you went about this calculation.

# %%
files <- fs::dir_ls("Data/", glob = "*.csv")

Complex_Refractive_Index <- read_csv(files, id = "filename")

Complex_Refractive_Index_df <- data.frame(Complex_Refractive_Index)

colnames(Complex_Refractive_Index_df) [1] <- "material_ID"
colnames(Complex_Refractive_Index_df) [2] <- "wavelength_n"
colnames(Complex_Refractive_Index_df) [4] <- "wavelength_k"
colnames(Complex_Refractive_Index_df) [6] <- "alpha"

# The following two lines of code are commented out, but you can use them if you want to see the dataframe
# Complex_Refractive_Index_df
# str(Complex_Refractive_Index_df)

# Customize the plot size
options(repr.plot.width = 10, repr.plot.height = 8)

# Plot of the real refractive index versus wavelength
ggplot(data = Complex_Refractive_Index_df, aes(y = n, x = wavelength_n, group = material_ID, color = material_ID)) +
  	geom_line() +
	theme_bw() +
  	theme(text = element_text(size = 30)) +
  	theme(axis.ticks.length = unit(-0.25, "cm")) +
	scale_color_discrete(name = "Material", labels = c("A", "B", "C", "D")) +
	ylab(expression(italic(n))) + 
	xlab(expression(italic(λ)~(nm)))

# Plot of the imaginary refractive index versus wavelength
ggplot(data = Complex_Refractive_Index_df, aes(y = k, x = wavelength_k, group = material_ID, color = material_ID)) +
  	geom_line() +
	theme_bw() +
  	theme(text = element_text(size = 30)) +
  	theme(axis.ticks.length = unit(-0.25, "cm")) +
	scale_color_discrete(name = "Material", labels = c("A", "B", "C", "D")) +
	ylab(expression(italic(k))) + 
	xlab(expression(italic(λ)~(nm))) +
	scale_y_log10(breaks = trans_breaks("log10", function(x) 10^x), labels = trans_format("log10", math_format(10^.x)), limits = c(0.01, 5))
# Out:
# Rows: 521 Columns: 6
# ── Column specification ────────────────────────────────────────────────────────
# Delimiter: ","
# dbl (5): λ,n (nm), n, λ,k (nm), k, α (cm⁻¹)
#
# ℹ Use `spec()` to retrieve the full column specification for this data.
# ℹ Specify the column types or set `show_col_types = FALSE` to quiet this message.
# Warning message in scale_y_log10(breaks = trans_breaks("log10", function(x) 10^x), :
# “log-10 transformation introduced infinite values.”
# Warning message:
# “Removed 9 rows containing missing values or values outside the scale range
# (`geom_line()`).”
# plot without title
# plot without title

# %% [markdown]
# ### Answer 1(a) - 15 points
#
# Explain here how you would determine the approximate $E_{g}$ from the curves above.

# %% [markdown]
# ## Answer 1(b) - 20 points
#
# Enter the appropximate $E_{g}$ for each material below:
#
# - Material A: $E_{g}$ =
# - Material B: $E_{g}$ =
# - Material C: $E_{g}$ =
# - Material D: $E_{g}$ =

# %% [markdown]
# ### Answer 1(c) - 20 points of extra credit
#
# Can you find the complex refractive index of one of the absorber or emitter materials featured in your literature search and/or datasheet and then create a new plot below adding this data as Material E?
#
# To do this, you'll need to create a CSV file with a similar format to that of the files included here. Then, you can feel free to use the code above and modify it to add the new curve to this figure. Here are a couple of places to find complex refractive index data.
#
# https://pvlighthouse.com.au/refractive-index-library
# https://refractiveindex.info/#google_vignette
# https://www.filmetrics.com/refractive-index-database

# %% [markdown]
# ### Problem 2
#
# Sometimes the following equation is given in textbooks to calculate reflectance at an interface with light at normal incidence with respect to the surface.
#
# Equation 1. $R$ = $\frac{(n_{1} - n_{2})^{2}}{(n_{1} + n_{2})^{2}}$
#
# The more complete equation is the following.
#
# Equation 2. $R$ = $\frac{(n_{1} - n_{2})^{2} + (κ_{1} - κ_{2})^{2}}{(n_{1} + n_{2})^{2} + (κ_{1} + κ_{2})^{2}}$
#
#
# Would equation 1 be an acceptable approximate for the following situations? Provide both an answer and an explanation for each case.
#
# (a) Reflectance at the interface between two dielectric materials (thickness of each greater than 1 mm)
#
# (b) Between a dielectric material and a metal (thickness of each greater than 1 mm)
#
# (c) Between a semiconductor and a semiconductor (thickness of each greater than 1 mm)
#
# (d) Between air and a semiconductor (thickness of each greater than 1 mm)
#
# (e) Between air and a semiconductor (thickness of each greater than 1 mm) coated with a thin film (thickness less than 200 nm)

# %% [markdown]
# ### Answer 2(a) - 10 points
#
# Provide your answer and explanation here.

# %% [markdown]
# ### Answer 2(b) - 10 points
#
# Provide your answer and explanation here.

# %% [markdown]
# ### Answer 2(c) - 10 points
#
# Provide your answer and explanation here.

# %% [markdown]
# ### Answer 2(d) - 10 points
#
# Provide your answer and explanation here.

# %% [markdown]
# ### Answer 2(e) - 10 points
#
# Provide your answer and explanation here.

# %% [markdown]
# ## Submission Instructions
#
# - Click "File" above and then "Export to PDF"
# - Then select "Export code view..."
# - Save the PDF file as EMA_6611_Datalab_1_YourLastName_YourFirstName_YourNID.pdf
# - Download your completed Table_1 Excel file and save it.
# - Upload both the PDF and the Excel file to Webcourses before the end of the day on October 7, 2024.
#
# Make sure to download a copy of this workbook and save it for your own use later.
