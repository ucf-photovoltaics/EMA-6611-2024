# %% [markdown]
# # EMA 6611 - DataLab Assignment 2
# Complete each of the steps below and submit this by **November 17, 2024**.

# %%
suppressPackageStartupMessages(library(tidyverse))

library(readr)
library(ggplot2)
library(tidyverse)
library(plyr)
library(dplyr)
library(readr)
library(scales)
library(reshape2)
# Out:
# ------------------------------------------------------------------------------
#
# You have loaded plyr after dplyr - this is likely to cause problems.
# If you need functions from both plyr and dplyr, please load plyr first, then dplyr:
# library(plyr); library(dplyr)
#
# ------------------------------------------------------------------------------
#
#
# Attaching package: ‘plyr’
#
#
# The following objects are masked from ‘package:dplyr’:
#
#     arrange, count, desc, failwith, id, mutate, rename, summarise,
#     summarize
#
#
# The following object is masked from ‘package:purrr’:
#
#     compact
#
#
#
# Attaching package: ‘scales’
#
#
# The following object is masked from ‘package:purrr’:
#
#     discard
#
#
# The following object is masked from ‘package:readr’:
#
#     col_factor
#
#
#
# Attaching package: ‘reshape2’
#
#
# The following object is masked from ‘package:tidyr’:
#
#     smiths

# %% [markdown]
# ### Task 1 - 5 points
#
# Rename this file as: EMA_6611_Datalab_2_YourLastName_YourFirstName_YourNID

# %% [markdown]
# ## Complete Literature Summary Table Version 1

# %% [markdown]
# ### Task 2 - 5 points
#
# - Download the Excel file in the Data folder for this workbook (on the right).
# - In the subsequent tasks, you will fill out this table as you did previously. Every row will represent one of the articles you found for the previous assignment where you created the BibTeX file or one of the datasheets you found previously.
# - Make sure you have all of the articles and datasheets saved on your computer and/or your prefered cloud storage location (e.g., OneDrive, Google Drive).

# %% [markdown]
# ### Task 3 - 20 points
#
# In the Excel file provided, you will notice columns A through J are all the same as before. Copy and paste your previous entries into the rows for these columns.
#
# However, make sure you make corrections to previous entries, especially if you received feedback from the instructor on this from the last assignment.

# %% [markdown]
# ### Task 4 - 100 points
#
# Now for your research articles and datasheets, fill out the following columns for each row of your table. As before, each row will represent each publication or datasheet.
#
# **Electron Selective Junction Location** - Remember, these semiconductor-based optoelectronic devices should have a electron contact and a hole contact. Select where the electron selective junction is located.
# - Front
# - Rear
# - NA
#
# **Electron Selective Junction Type** - Select the type of electron selective junction used in this device.
# - Homojunction
# - Heterojunction
# - NA
#
# **Hole Selective Junction Location** - Select where the hole selective junction is located.
# - Front
# - Rear
# - NA
#
# **Hole Selective Junction Type** - Select the type of hole selective junction used in this device.
# - Homojunction
# - Heterojunction
# - NA
#
# **Metallization Type for Electron Selective Junction** - Select the type of metallization design used for the electron selective junction.
# - Full Area
# - Patterned Grid
# - NA
#
# **Metallization Material(s) for Electron Selective Junction** - Type the material(s) used for the metallization of the electron selective junction. Use the abbreviated chemical symbol of the element(s). If multiple metals are used, type the element that first contacts the junction, followed by a /, and then the next element and so forth. For example, if titanium is first in contact with the electron selective junction (e.g., n-type silicon layer for someone working on a silicon photovoltaic cell), followed by palladium, and then silver, you should enter the following: Ti/Pd/Ag
#
# **Metallization Type for Hole Selective Junction** - Select the type of metallization design used for the hole selective junction.
# - Full Area
# - Patterned Grid
# - NA
#
# **Metallization Material(s) for Electron Selective Junction** - Type the material(s) used for the metallization of the hole selective junction. Use the The same format described above.

# %% [markdown]
# ### Task 5 - 80 points
#
# The next columns all related to the performance of the devices. This is important, because it completes the process-structure-properties-performance relationship and performance is often what dictates a device's commercial viability. Fill out the four columns associated with the type of device you are researching. Leave the remaining eight columns blank since they do not pertain to your device. Here is some guidance:
#
# - Enter single numerical values in these columns. Not a range or multiple values. Later, you will plot these, and if you include non-numerical characters this will not be possible.
# - If multiple values are reported for these parameters, enter the values associated with the best devices in that article or datasheet.
# - Make sure to pay attention to the units and enter the numerical value associated with the correct units. As graduate students in a STEM field, you are certainly aware of the importance of this, but make sure to be diligent here.
# - If you are unsure about any of these parameters, you need to read the articles a bit more deeply and look for review articles that define these. Feel free to reach out to your classmates that you know are working on the same devices to make sure you are on the same page. If you are still unsure, reach out to the instructor on Slack.

# %% [markdown]
# ### Task 6 - 5 points
#
# Replace the empy Table_2.xlsx Excel file in this workbook with your completed file. Do not change the filename. Make sure to save a copy of this on your computer as well!
#
# You can do this by first deleting the empty Excel file in the Data folder within this workbook. Then, click the three dots near the Data folder and click "Upload into folder" and select the new file with completed entries.

# %% [markdown]
# ### Task 7 - 20 points of extra credit
#
# - Create a CSV file from the Table_2.xlsx file
# - Read in the CSV file
# - Turn it into a dataframe
# - Plot at least on of the performance paramters vs. year as a barchart

# %% [markdown]
# ## Solve the Following Problem Set

# %% [markdown]
# ## Problem 1 - 20 points
# Determine the non-radiative carrier lifetime ($\tau_{nr}$) of a light emitting diode (LED) knowing the following.
#
# - The measured external quantum efficiency ($\eta_{EQE}$) is $0.87$
# - The optical quantum efficiency ($\eta_{optical}$) is $0.95$
# - The radiative carrier lifetime ($\tau_{r}$) is $1.3$ $\mu s$

# %% [markdown]
# ## Answer 1
#
# Enter your answer to problem 1 here.

# %% [markdown]
# ## Problem 2 - 30 points
#
# Given the electronic defect levels for various elemental impurities in Ge (see the figure below), please list the following:
#
# (a) elements that would likely make good donor impurities;
#
# (b) elements that would likely make good acceptor impurities; and
#
# (c) elements to avoid due to the possible formation of recombination centers.
#
# ![Ge_Defect_Levels](Ge_Defect_Levels)

# %% [markdown]
# ## Answer 2(a) - Good Donor Impurties
#
# Enter your answer for problem 2(a) here.

# %% [markdown]
# ## Answer 2(b) - Good Acceptor Impurties
#
# Enter your answer for problem 2(b) here.

# %% [markdown]
# ## Answer 2(c) - Possible Recombination Centers
#
# Enter your answer for problem 2(c) here.

# %% [markdown]
# ## Problem 3 - 50 points
#
# Calculate the doping distribution of arsenic at distances of $10$, $20$, $30$, $40$, and $45$ $cm$ from the seed in a silicon ingot $50$ $cm$ long that has been pulled from a melt with an initial doping concentration of $10^{17}$ $cm^{–3}$.
#
# Then, plot this distribution by inserting the calculated concentrations in the dataframe called _Doping_Distribution.csv_. To do this, do the following steps:
#
# 1. Download _Doping_Distribution.csv_ from the files tab on the top left
# 2. Add the calculated values at each distance to this file
# 3. Upload your new _Doping_Distribution.csv_ file to replace the old file
# 4. Run the code below to get your plot
#
# **Notes**
#
# In the _Doping_Distribution.csv_ file,
# - _fractional_distance_ refers to $x/x_{total}$ and should be unitless
# - _concentration_in_the_solid_ refers to $C_{s}$ and should be in $cm^{-3}$

# %%
# This reads the data in
doping_distribution <- read_csv('Data/Doping_Distribution.csv', show_col_types = FALSE)

# This creates the dataframe
doping_distribution_df <- data.frame(doping_distribution)

# This displays the dataframe so you can make 
doping_distribution

# Replace the placehoder values shown for concentratin_in_the_solid with your calculated answers
# Out:
#   fractional_distance concentration_in_the_solid
# 1 0.2                 1e+14
# 2 0.4                 1e+14
# 3 0.6                 1e+14
# 4 0.8                 1e+14
# 5 0.9                 1e+14

# %% [markdown]
# ## Answer 3
#
# Run the code to provide your final plot below for problem 3.

# %%
ggplot(data = doping_distribution, aes(y = concentration_in_the_solid, x = fractional_distance)) +
  	geom_point(size = 5) +
	theme_bw() +
  	theme(text = element_text(size = 24)) +
  	theme(axis.ticks.length = unit(-0.25, "cm")) +
	ylab(expression(italic(C)[s]~(cm^{-3}))) + 
	xlab(expression(italic(x)/italic(x[total])))
# Out:
# plot without title

# %% [markdown]
# ## Submission Instructions
#
# - Click "File" above and then "Export to PDF"
# - Then select "Export code view..."
# - Save the PDF file as EMA_6611_Datalab_2_YourLastName_YourFirstName_YourNID.pdf
# - Download your completed Table_2 Excel file and save it.
# - Upload both the PDF and the Excel file to Webcourses before the end of the day on November 17, 2024.
#
# Make sure to download a copy of this workbook and save it for your own use later.
